# %% [markdown]
# # Banking Assignment — Functions, Lambda, map, filter, and reduce (100 Questions with Hints)
#
# An unsolved assessment notebook using accounts, deposits, withdrawals, transfers, cards, loans, KYC, fraud monitoring, reconciliation, and audit trails.
#
# **Structure:** 30 easy + 40 medium + 30 difficult = **100 questions**.

# %% [markdown]
# ## Student instructions
#
# Solve all questions using banking scenarios. Practice function design, parameters, returns, scope, docstrings, type hints, pure functions, higher-order functions, closures, decorators, recursion, lambda expressions, map, filter, reduce, pipelines, and testing. Do not store real customer data, credentials, PINs, or complete card numbers. Each question includes a graduated hint but intentionally has no solution.
#
# **Recommended workflow:** write assumptions, implement the smallest correct function/class, test normal and edge cases, then explain your design.

# %% [markdown]
# ---
#
# ## Easy
#
# Fundamentals and direct applications.

# %% [markdown]
# ### Q1. Write a function for line total for banking case 1; use sample reference `ACC-1001` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def line_total(transaction_fee: float, transaction_count: int) -> float:
    """Calculates overall processing expenses for dynamic system transaction batches."""
    return transaction_fee * transaction_count

result = line_total(5.00, 3)
print("Reference:", "ACC-1001")
print("Line total:", result)
# Out:
# Reference: ACC-1001
# Line total: 15.0

# %% [markdown]
# ### Q2. Return a discounted amount for banking case 1; use sample reference `ACC-1002` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def discounted_amount(amount, discount_percent):
    return amount - (amount * discount_percent / 100)
result = discounted_amount(2000, 10)
print("Reference:", "ACC-1002")
print("Discounted amount:", result)
# Out:
# Reference: ACC-1002
# Discounted amount: 1800.0

# %% [markdown]
# ### Q3. Use a default tax rate for banking case 1; use sample reference `ACC-1003` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def add_tax(amount, tax_rate=5):
    return amount + (amount * tax_rate / 100)
result = add_tax(1000)
print("Reference:", "ACC-1003")
print("Amount with tax:", result)
# Out:
# Reference: ACC-1003
# Amount with tax: 1050.0

# %% [markdown]
# ### Q4. Accept keyword arguments for a account for banking case 1; use sample reference `ACC-1004` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def create_account(**details):
    return details
account = create_account(
    account_id="ACC-1004",
    holder="Sample User",
    balance=5000
    )
print("Account details:", account)
# Out:
# Account details: {'account_id': 'ACC-1004', 'holder': 'Sample User', 'balance': 5000}

# %% [markdown]
# ### Q5. Return multiple inventory values for banking case 1; use sample reference `ACC-1005` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def account_summary(balance: float, total_deposits: float, total_withdrawals: float) -> tuple:
    """Computes basic ledger metrics for periodic reconciliation audits in one pass."""
    final_balance = balance + total_deposits - total_withdrawals
    return balance, total_deposits, total_withdrawals, final_balance


result = account_summary(10000.00, 5000.00, 2000.00)

print("Reference:", "ACC-1005")
print("Original Opening Balance:", result[0])
print("Accumulated T-Ledger Deposits:", result[1])
print("Accumulated T-Ledger Withdrawals:", result[2])
print("Audited Final Adjusted Balance:", result[3])
# Out:
# Reference: ACC-1005
# Original Opening Balance: 10000.0
# Accumulated T-Ledger Deposits: 5000.0
# Accumulated T-Ledger Withdrawals: 2000.0
# Audited Final Adjusted Balance: 13000.0

# %% [markdown]
# ### Q6. Write a account docstring for banking case 1; use sample reference `ACC-1006` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def calculate_balance(opening_balance, deposit, withdrawal):
    """
    Calculate the final bank account balance.

    Parameters:
        opening_balance: Starting account balance.
        deposit: Amount deposited.
        withdrawal: Amount withdrawn.

    Returns:
        Final account balance.
    """
    return opening_balance + deposit - withdrawal


result = calculate_balance(8000, 3000, 1500)

print("Reference:", "ACC-1006")
print("Final balance:", result)
print("Docstring:", calculate_balance.__doc__.strip())
# Out:
# Reference: ACC-1006
# Final balance: 9500
# Docstring: Calculate the final bank account balance.
#
# Parameters:
#     opening_balance: Starting account balance.
#     deposit: Amount deposited.
#     withdrawal: Amount withdrawn.
#
# Returns:
#     Final account balance.

# %% [markdown]
# ### Q7. Add type hints to a amount function for banking case 1; use sample reference `ACC-1007` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def calculate_amount(amount: float, fee: float) -> float:
    return amount + fee
result = calculate_amount(1500.0, 50.0)
print("Reference:", "ACC-1007")
print("Total amount:", result)
# Out:
# Reference: ACC-1007
# Total amount: 1550.0

# %% [markdown]
# ### Q8. Use *args to total purchases for banking case 1; use sample reference `ACC-1008` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def total_purchases(*amounts):
    return sum(amounts)
result = total_purchases(500, 1200, 750, 300)
print("Reference:", "ACC-1008")
print("Total purchases:", result)
# Out:
# Reference: ACC-1008
# Total purchases: 2750

# %% [markdown]
# ### Q9. Use **kwargs for account attributes for banking case 1; use sample reference `ACC-1009` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def account_attributes(**attributes):
    return attributes
account = account_attributes(
    account_id="ACC-1009",
    account_type="Savings",
    balance=7500,
    status="Active"
)
print("Reference:", "ACC-1009")
print("Account attributes:", account)
# Out:
# Reference: ACC-1009
# Account attributes: {'account_id': 'ACC-1009', 'account_type': 'Savings', 'balance': 7500, 'status': 'Active'}

# %% [markdown]
# ### Q10. Create a one-line amount lambda for banking case 1; use sample reference `ACC-1010` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
calculate_amount = lambda amount, fee: amount + fee
result = calculate_amount(2000, 100)
print("Reference:", "ACC-1010")
print("Total amount:", result)
# Out:
# Reference: ACC-1010
# Total amount: 2100

# %% [markdown]
# ### Q11. Map amounts to tax-inclusive amounts for banking case 1; use sample reference `ACC-1011` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
amounts = [1000, 2000, 3000]
tax_rate = 18
tax_inclusive = list(map(lambda x: x + (x * tax_rate / 100), amounts))
print("Original amounts:", amounts)
print("Tax-inclusive amounts:", tax_inclusive)
# Out:
# Original amounts: [1000, 2000, 3000]
# Tax-inclusive amounts: [1180.0, 2360.0, 3540.0]

# %% [markdown]
# ### Q12. Filter in-balance accounts for banking case 1; use sample reference `ACC-1012` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
accounts = [
    {"id": "ACC-1012", "balance": 50000},
    {"id": "ACC-2001", "balance": -500},
    {"id": "ACC-2002", "balance": 25000}
]
in_balance = list(filter(lambda account: account["balance"] >= 0, accounts))
print("In-balance accounts:", in_balance)
# Out:
# In-balance accounts: [{'id': 'ACC-1012', 'balance': 50000}, {'id': 'ACC-2002', 'balance': 25000}]

# %% [markdown]
# ### Q13. Reduce a basket to its total for banking case 1; use sample reference `ACC-1013` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
basket = [500, 1200, 750, 300]
total = reduce(lambda x, y: x + y, basket)
print("Basket:", basket)
print("Total:", total)
# Out:
# Basket: [500, 1200, 750, 300]
# Total: 2750

# %% [markdown]
# ### Q14. Demonstrate local scope for banking case 1; use sample reference `ACC-1014` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def calculate_balance():
    balance = 25000
    return balance
print("Local balance:", calculate_balance())
# Out:
# Local balance: 25000

# %% [markdown]
# ### Q15. Write a predicate for premium accounts for banking case 1; use sample reference `ACC-1015` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
accounts = [
    {"id": "ACC-1015", "balance": 150000},
    {"id": "ACC-2001", "balance": 50000},
    {"id": "ACC-2002", "balance": 250000}
]
is_premium = lambda account: account["balance"] >= 100000
premium_accounts = list(filter(is_premium, accounts))
print("Premium accounts:", premium_accounts)
# Out:
# Premium accounts: [{'id': 'ACC-1015', 'balance': 150000}, {'id': 'ACC-2002', 'balance': 250000}]

# %% [markdown]
# ### Q16. Write a function for line total for banking case 2; use sample reference `ACC-1016` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def line_total(transaction_fee: float, transaction_count: int) -> float:
    """Calculates total processing expenses for bulk automated clearing house batches."""
    return transaction_fee * transaction_count

print("Line total:", line_total(7.50, 4))
# Out:
# Line total: 30.0

# %% [markdown]
# ### Q17. Return a discounted amount for banking case 2; use sample reference `ACC-1017` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def discounted_amount(amount, discount=15):
    return amount - (amount * discount / 100)
print("Discounted amount:", discounted_amount(4000))
# Out:
# Discounted amount: 3400.0

# %% [markdown]
# ### Q18. Use a default tax rate for banking case 2; use sample reference `ACC-1018` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def final_amount(amount, tax_rate=18):
    return amount + (amount * tax_rate / 100)
print("Final amount:", final_amount(2500))
# Out:
# Final amount: 2950.0

# %% [markdown]
# ### Q19. Accept keyword arguments for a account for banking case 2; use sample reference `ACC-1019` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def create_account(**details):
    return details
account = create_account(
    account_id="ACC-1019",
    balance=40000,
    account_type="Current"
)
print("Account:", account)
# Out:
# Account: {'account_id': 'ACC-1019', 'balance': 40000, 'account_type': 'Current'}

# %% [markdown]
# ### Q20. Return multiple inventory values for banking case 2; use sample reference `ACC-1020` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def account_summary(account_id, balance, status):
    return account_id, balance, status
summary = account_summary("ACC-1020", 60000, "Active")
print("Account summary:", summary)
# Out:
# Account summary: ('ACC-1020', 60000, 'Active')

# %% [markdown]
# ### Q21. Write a account docstring for banking case 2; use sample reference `ACC-1021` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def get_balance(account):
    """Return the balance of a bank account."""
    return account["balance"]
account = {"account_id": "ACC-1021", "balance": 25000}
print(get_balance(account))
# Out:
# 25000

# %% [markdown]
# ### Q22. Add type hints to a amount function for banking case 2; use sample reference `ACC-1022` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def line_total(transaction_fee: float, count: int = 1) -> float:
    """Returns dynamic standard charges multiplied by ledger line count occurrences."""
    return round(transaction_fee * count, 2)

print(line_total(12.00, 2))
# Out:
# 24.0

# %% [markdown]
# ### Q23. Use *args to total purchases for banking case 2; use sample reference `ACC-1023` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def total_purchases(*amounts):
    return sum(amounts)
print(total_purchases(1200, 800, 1500, 500))
# Out:
# 4000

# %% [markdown]
# ### Q24. Use **kwargs for account attributes for banking case 2; use sample reference `ACC-1024` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def account_details(**attributes):
    return attributes
account = account_details(
    account_id="ACC-1024",
    balance=30000,
    account_type="Savings"
)
print(account)
# Out:
# {'account_id': 'ACC-1024', 'balance': 30000, 'account_type': 'Savings'}

# %% [markdown]
# ### Q25. Create a one-line amount lambda for banking case 2; use sample reference `ACC-1025` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
amount = lambda fee, count: fee * count
print(amount(15.00, 2))
# Out:
# 30.0

# %% [markdown]
# ### Q26. Map amounts to tax-inclusive amounts for banking case 2; use sample reference `ACC-1026` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
amounts = [1000, 2000, 3000]
result = list(map(lambda amount: round(amount * 1.18, 2), amounts))
print(result)
# Out:
# [1180.0, 2360.0, 3540.0]

# %% [markdown]
# ### Q27. Filter in-balance accounts for banking case 2; use sample reference `ACC-1027` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
accounts = [
    {"account_id": "ACC-1027", "balance": 15000},
    {"account_id": "ACC-1028", "balance": -5000},
    {"account_id": "ACC-1029", "balance": 25000}
]
result = list(filter(lambda account: account["balance"] >= 0, accounts))
print(result)
# Out:
# [{'account_id': 'ACC-1027', 'balance': 15000}, {'account_id': 'ACC-1029', 'balance': 25000}]

# %% [markdown]
# ### Q28. Reduce a basket to its total for banking case 2; use sample reference `ACC-1028` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
basket = [1200, 2500, 1800, 500]
total = reduce(lambda a, b: a + b, basket, 0)
print(total)
# Out:
# 6000

# %% [markdown]
# ### Q29. Demonstrate local scope for banking case 2; use sample reference `ACC-1029` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def account_balance():
    balance = 22000
    return balance
print(account_balance())
# Out:
# 22000

# %% [markdown]
# ### Q30. Write a predicate for premium accounts for banking case 2; use sample reference `ACC-1030` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def is_premium(account):
    return account["balance"] >= 50000
account = {"account_id": "ACC-1030", "balance": 75000}
print(is_premium(account))
# Out:
# True

# %% [markdown]
# ---
#
# ## Medium
#
# Reusable components and multi-step workflows.

# %% [markdown]
# ### Q31. Compose discount and tax functions for banking case 1; use sample reference `ACC-1031` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def discount(amount):
    return amount * 0.90
def tax(amount):
    return amount * 1.18
def final_amount(amount):
    return round(tax(discount(amount)), 2)
print(final_amount(10000))
# Out:
# 10620.0

# %% [markdown]
# ### Q32. Sort accounts with a lambda key for banking case 1; use sample reference `ACC-1032` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
accounts = [
    {"account_id": "ACC-1032", "balance": 25000},
    {"account_id": "ACC-1033", "balance": 10000},
    {"account_id": "ACC-1034", "balance": 40000}
]
result = sorted(accounts, key=lambda account: account["balance"])
print(result)
# Out:
# [{'account_id': 'ACC-1033', 'balance': 10000}, {'account_id': 'ACC-1032', 'balance': 25000}, {'account_id': 'ACC-1034', 'balance': 40000}]

# %% [markdown]
# ### Q33. Group accounts using a helper function for banking case 1; use sample reference `ACC-1033` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def group_account(account):
    if account["balance"] >= 50000:
        return "Premium"
    return "Regular"
account = {"account_id": "ACC-1033", "balance": 60000}
print(group_account(account))
# Out:
# Premium

# %% [markdown]
# ### Q34. Create a closure for category discounts for banking case 1; use sample reference `ACC-1034` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def create_discount(rate):
    def discount(amount):
        return round(amount * (1 - rate), 2)
    return discount
premium_discount = create_discount(0.20)
print(premium_discount(10000))
# Out:
# 8000.0

# %% [markdown]
# ### Q35. Write a decorator that logs checkout calls for banking case 1; use sample reference `ACC-1035` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def log_checkout(func):
    def wrapper(amount):
        print("Checkout called")
        return func(amount)
    return wrapper
@log_checkout
def checkout(amount):
    return amount
print(checkout(5000))
# Out:
# Checkout called
# 5000

# %% [markdown]
# ### Q36. Build a map-filter-reduce transactions pipeline for banking case 1; use sample reference `ACC-1036` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce

transactions = [1000, -500, 2000, -200, 3000]

credits = filter(lambda x: x > 0, transactions)

amounts = map(lambda x: x * 0.99, credits)


total = reduce(lambda a, b: a + b, amounts, 0)
print(total)
# Out:
# 5940.0

# %% [markdown]
# ### Q37. Partially apply a tax function for banking case 1; use sample reference `ACC-1037` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import partial
def add_tax(amount, rate):
    return round(amount * (1 + rate), 2)
gst = partial(add_tax, rate=0.18)
print(gst(10000))
# Out:
# 11800.0

# %% [markdown]
# ### Q38. Use enumerate and zip in a balance report for banking case 1; use sample reference `ACC-1038` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
accounts = ["ACC-1038", "ACC-1039", "ACC-1040"]
balances = [25000, 18000, 32000]
for number, (account, balance) in enumerate(zip(accounts, balances), 1):
    print(number, account, balance)
# Out:
# 1 ACC-1038 25000
# 2 ACC-1039 18000
# 3 ACC-1040 32000

# %% [markdown]
# ### Q39. Write a generator for low-balance accounts for banking case 1; use sample reference `ACC-1039` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def low_balance(accounts):
    for account in accounts:
        if account["balance"] < 10000:
            yield account
accounts = [
    {"account_id": "ACC-1039", "balance": 5000},
    {"account_id": "ACC-1040", "balance": 15000}
]
print(list(low_balance(accounts)))
# Out:
# [{'account_id': 'ACC-1039', 'balance': 5000}]

# %% [markdown]
# ### Q40. Implement recursive category total for banking case 1; use sample reference `ACC-1040` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def category_total(amounts):
    if not amounts:
        return 0
    return amounts[0] + category_total(amounts[1:])
amounts = [1000, 2000, 3000]
print(category_total(amounts))
# Out:
# 6000

# %% [markdown]
# ### Q41. Validate arguments with a wrapper for banking case 1; use sample reference `ACC-1041` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def validate(func):
    def wrapper(amount):
        if not isinstance(amount, (int, float)):
            raise TypeError("Amount must be numeric")
        if amount < 0:
            raise ValueError("Amount cannot be negative")
        return func(amount)
    return wrapper
@validate
def deposit(amount):
    return amount
print(deposit(5000))
# Out:
# 5000

# %% [markdown]
# ### Q42. Return a function selected by interest offer type for banking case 1; use sample reference `ACC-1042` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def regular_interest(amount):
    return amount * 0.04
def premium_interest(amount):
    return amount * 0.06
def get_interest(offer_type):
    if offer_type == "premium":
        return premium_interest
    return regular_interest
interest = get_interest("premium")
print(interest(10000))
# Out:
# 600.0

# %% [markdown]
# ### Q43. Keep a pricing function pure for banking case 1; use sample reference `ACC-1043` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def calculate_price(price, tax):
    return round(price + (price * tax), 2)
price = 10000
result = calculate_price(price, 0.18)
print(result)
print(price)
# Out:
# 11800.0
# 10000

# %% [markdown]
# ### Q44. Calculate basket metrics in one pass for banking case 1; use sample reference `ACC-1044` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def basket_metrics(prices):
    total = sum(prices)
    count = len(prices)
    average = total / count if count else 0
    return total, count, average
prices = [1000, 2000, 3000]
print(basket_metrics(prices))
# Out:
# (6000, 3, 2000.0)

# %% [markdown]
# ### Q45. Unit-test a reusable banking function for banking case 1; use sample reference `ACC-1045` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def calculate_interest(balance, rate):
    return balance * rate
def test_calculate_interest():
    assert calculate_interest(10000, 0.05) == 500
    assert calculate_interest(0, 0.05) == 0
test_calculate_interest()
print("All tests passed")
# Out:
# All tests passed

# %% [markdown]
# ### Q46. Compose discount and tax functions for banking case 2; use sample reference `ACC-1046` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def discount(amount):
    return amount * 0.90
def tax(amount):
    return amount * 1.18
def final_amount(amount):
    return round(tax(discount(amount)), 2)
print(final_amount(20000))
# Out:
# 21240.0

# %% [markdown]
# ### Q47. Sort accounts with a lambda key for banking case 2; use sample reference `ACC-1047` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
accounts = [
    {"account_id": "ACC-1047", "balance": 30000},
    {"account_id": "ACC-1048", "balance": 10000},
    {"account_id": "ACC-1049", "balance": 50000}
]
result = sorted(accounts, key=lambda account: account["balance"])
print(result)
# Out:
# [{'account_id': 'ACC-1048', 'balance': 10000}, {'account_id': 'ACC-1047', 'balance': 30000}, {'account_id': 'ACC-1049', 'balance': 50000}]

# %% [markdown]
# ### Q48. Group accounts using a helper function for banking case 2; use sample reference `ACC-1048` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def account_group(account):
    if account["balance"] >= 50000:
        return "Premium"
    elif account["balance"] >= 20000:
        return "Standard"
    return "Basic"
account = {"account_id": "ACC-1048", "balance": 30000}
print(account_group(account))
# Out:
# Standard

# %% [markdown]
# ### Q49. Create a closure for category discounts for banking case 2; use sample reference `ACC-1049` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def create_discount(rate):
    def discount(amount):
        return round(amount * (1 - rate), 2)
    return discount
premium_discount = create_discount(0.20)
print(premium_discount(15000))
# Out:
# 12000.0

# %% [markdown]
# ### Q50. Write a decorator that logs checkout calls for banking case 2; use sample reference `ACC-1050` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def log_checkout(func):
    def wrapper(amount):
        print("Checkout called")
        return func(amount)
    return wrapper
@log_checkout
def checkout(amount):
    return amount
print(checkout(8000))
# Out:
# Checkout called
# 8000

# %% [markdown]
# ### Q51. Build a map-filter-reduce transactions pipeline for banking case 2; use sample reference `ACC-1051` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
transactions = [1000, -500, 2000, -300, 1500]
credits = filter(lambda x: x > 0, transactions)
amounts = map(lambda x: x * 1.05, credits)
total = reduce(lambda a, b: a + b, amounts, 0)
print(round(total, 2))
# Out:
# 4725.0

# %% [markdown]
# ### Q52. Partially apply a tax function for banking case 2; use sample reference `ACC-1052` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import partial
def add_tax(amount, rate):
    return round(amount * (1 + rate), 2)
gst = partial(add_tax, rate=0.18)
print(gst(10000))
# Out:
# 11800.0

# %% [markdown]
# ### Q53. Use enumerate and zip in a balance report for banking case 2; use sample reference `ACC-1053` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
accounts = ["ACC-1053", "ACC-1054", "ACC-1055"]
balances = [20000, 35000, 15000]
for number, (account, balance) in enumerate(zip(accounts, balances), 1):
    print(number, account, balance)
# Out:
# 1 ACC-1053 20000
# 2 ACC-1054 35000
# 3 ACC-1055 15000

# %% [markdown]
# ### Q54. Write a generator for low-balance accounts for banking case 2; use sample reference `ACC-1054` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def low_balance_accounts(accounts):
    for account in accounts:
        if account["balance"] < 10000:
            yield account
accounts = [
    {"account_id": "ACC-1054", "balance": 7000},
    {"account_id": "ACC-1055", "balance": 15000}
]
print(list(low_balance_accounts(accounts)))
# Out:
# [{'account_id': 'ACC-1054', 'balance': 7000}]

# %% [markdown]
# ### Q55. Implement recursive category total for banking case 2; use sample reference `ACC-1055` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def category_total(amounts):
    if not amounts:
        return 0
    return amounts[0] + category_total(amounts[1:])
amounts = [1500, 2500, 3000]
print(category_total(amounts))
# Out:
# 7000

# %% [markdown]
# ### Q56. Validate arguments with a wrapper for banking case 2; use sample reference `ACC-1056` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def validate(func):
    def wrapper(amount):
        if not isinstance(amount, (int, float)):
            raise TypeError("Amount must be numeric")
        if amount < 0:
            raise ValueError("Amount cannot be negative")
        return func(amount)
    return wrapper
@validate
def deposit(amount):
    return amount
print(deposit(5000))
# Out:
# 5000

# %% [markdown]
# ### Q57. Return a function selected by interest offer type for banking case 2; use sample reference `ACC-1057` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def regular_interest(amount):
    return amount * 0.04
def premium_interest(amount):
    return amount * 0.06
def get_interest(offer):
    return premium_interest if offer == "premium" else regular_interest
interest = get_interest("premium")
print(interest(10000))
# Out:
# 600.0

# %% [markdown]
# ### Q58. Keep a pricing function pure for banking case 2; use sample reference `ACC-1058` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def calculate_price(price, tax):
    return round(price + price * tax, 2)
price = 10000
print(calculate_price(price, 0.18))
print(price)
# Out:
# 11800.0
# 10000

# %% [markdown]
# ### Q59. Calculate basket metrics in one pass for banking case 2; use sample reference `ACC-1059` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def basket_metrics(amounts):
    total = sum(amounts)
    count = len(amounts)
    average = total / count if count else 0
    return total, count, average
amounts = [1000, 2000, 3000]
print(basket_metrics(amounts))
# Out:
# (6000, 3, 2000.0)

# %% [markdown]
# ### Q60. Unit-test a reusable banking function for banking case 2; use sample reference `ACC-1060` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def calculate_interest(balance, rate):
    return balance * rate
def test_interest():
    assert calculate_interest(10000, 0.05) == 500
    assert calculate_interest(0, 0.05) == 0
test_interest()
print("All tests passed")
# Out:
# All tests passed

# %% [markdown]
# ### Q61. Compose discount and tax functions for banking case 3; use sample reference `ACC-1061` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def discount(amount):
    return amount * 0.90
def tax(amount):
    return amount * 1.18
def final_amount(amount):
    return round(tax(discount(amount)), 2)
print(final_amount(10000))
# Out:
# 10620.0

# %% [markdown]
# ### Q62. Sort accounts with a lambda key for banking case 3; use sample reference `ACC-1062` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
accounts = [
    {"account_id": "ACC-1062", "balance": 25000},
    {"account_id": "ACC-1063", "balance": 10000},
    {"account_id": "ACC-1064", "balance": 40000}
]
result = sorted(accounts, key=lambda account: account["balance"])
print(result)
# Out:
# [{'account_id': 'ACC-1063', 'balance': 10000}, {'account_id': 'ACC-1062', 'balance': 25000}, {'account_id': 'ACC-1064', 'balance': 40000}]

# %% [markdown]
# ### Q63. Group accounts using a helper function for banking case 3; use sample reference `ACC-1063` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def account_group(account):
    if account["balance"] >= 50000:
        return "Premium"
    return "Regular"
account = {"account_id": "ACC-1063", "balance": 60000}
print(account_group(account))
# Out:
# Premium

# %% [markdown]
# ### Q64. Create a closure for category discounts for banking case 3; use sample reference `ACC-1064` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def create_discount(rate):
    def discount(amount):
        return round(amount * (1 - rate), 2)
    return discount
premium_discount = create_discount(0.20)
print(premium_discount(15000))
# Out:
# 12000.0

# %% [markdown]
# ### Q65. Write a decorator that logs checkout calls for banking case 3; use sample reference `ACC-1065` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def log_checkout(func):
    def wrapper(amount):
        print("Checkout called")
        return func(amount)
    return wrapper
@log_checkout
def checkout(amount):
    return amount
print(checkout(5000))
# Out:
# Checkout called
# 5000

# %% [markdown]
# ### Q66. Build a map-filter-reduce transactions pipeline for banking case 3; use sample reference `ACC-1066` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
transactions = [1000, -500, 2000, -300, 1500]
credits = filter(lambda x: x > 0, transactions)
amounts = map(lambda x: x * 1.05, credits)
total = reduce(lambda a, b: a + b, amounts, 0)
print(round(total, 2))
# Out:
# 4725.0

# %% [markdown]
# ### Q67. Partially apply a tax function for banking case 3; use sample reference `ACC-1067` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import partial
def add_tax(amount, rate):
    return round(amount * (1 + rate), 2)
gst = partial(add_tax, rate=0.18)
print(gst(10000))
# Out:
# 11800.0

# %% [markdown]
# ### Q68. Use enumerate and zip in a balance report for banking case 3; use sample reference `ACC-1068` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
accounts = ["ACC-1068", "ACC-1069", "ACC-1070"]
balances = [20000, 35000, 15000]
for number, (account, balance) in enumerate(zip(accounts, balances), 1):
    print(number, account, balance)
# Out:
# 1 ACC-1068 20000
# 2 ACC-1069 35000
# 3 ACC-1070 15000

# %% [markdown]
# ### Q69. Write a generator for low-balance accounts for banking case 3; use sample reference `ACC-1069` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def low_balance(accounts):
    for account in accounts:
        if account["balance"] < 10000:
            yield account
accounts = [
    {"account_id": "ACC-1069", "balance": 7000},
    {"account_id": "ACC-1070", "balance": 15000}
]
print(list(low_balance(accounts)))
# Out:
# [{'account_id': 'ACC-1069', 'balance': 7000}]

# %% [markdown]
# ### Q70. Implement recursive category total for banking case 3; use sample reference `ACC-1070` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def category_total(amounts):
    if not amounts:
        return 0
    return amounts[0] + category_total(amounts[1:])
amounts = [1500, 2500, 3000]
print(category_total(amounts))
# Out:
# 7000

# %% [markdown]
# ---
#
# ## Difficult
#
# Architecture, edge cases, and end-to-end banking systems.

# %% [markdown]
# ### Q71. Design a configurable transformation pipeline for banking case 1; use sample reference `ACC-1071` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def pipeline(amount, discount_rate, tax_rate):
    amount = amount * (1 - discount_rate)
    return round(amount * (1 + tax_rate), 2)
print(pipeline(10000, 0.10, 0.18))
# Out:
# 10620.0

# %% [markdown]
# ### Q72. Implement memoized demand calculation for banking case 1; use sample reference `ACC-1072` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import lru_cache

@lru_cache(maxsize=128)
def calculate_yield(rate_tier: float, account_count: int) -> float:
    """Optimized tracking metrics system for institutional savings tier packages."""
    return rate_tier * account_count

print(calculate_yield(50.0, 10))
print(calculate_yield(50.0, 10))
# Out:
# 500.0
# 500.0

# %% [markdown]
# ### Q73. Build a decorator with arguments for banking case 1; use sample reference `ACC-1073` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def log_message(message):
    def decorator(func):
        def wrapper(amount):
            print(message)
            return func(amount)
        return wrapper
    return decorator
@log_message("Banking transaction processed")
def deposit(amount):
    return amount
print(deposit(5000))
# Out:
# Banking transaction processed
# 5000

# %% [markdown]
# ### Q74. Create a function registry for interest offers for banking case 1; use sample reference `ACC-1074` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def regular(amount):
    return amount * 0.04
def premium(amount):
    return amount * 0.06
offers = {
    "regular": regular,
    "premium": premium
}
print(offers["premium"](10000))
# Out:
# 600.0

# %% [markdown]
# ### Q75. Implement a currying example for amounts for banking case 1; use sample reference `ACC-1075` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def calculate_amount(base_fee: float):
    """Higher-order currying structural pattern to evaluate complex balance sheets."""
    def with_count(count: int):
        return base_fee * count
    return with_count

amount = calculate_amount(15.00)
print(amount(3))
# Out:
# 45.0

# %% [markdown]
# ### Q76. Compare lazy generators with eager map results for banking case 1; use sample reference `ACC-1076` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
amounts = [1000, 2000, 3000]
lazy = (amount * 1.05 for amount in amounts)
eager = list(map(lambda amount: amount * 1.05, amounts))
print(list(lazy))
print(eager)
# Out:
# [1050.0, 2100.0, 3150.0]
# [1050.0, 2100.0, 3150.0]

# %% [markdown]
# ### Q77. Write a robust reduce for grouped totals for banking case 1; use sample reference `ACC-1077` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
transactions = [
    ("Savings", 1000),
    ("Current", 2000),
    ("Savings", 1500),
    ("Current", 500)
]
def add_total(result, transaction):
    category, amount = transaction
    result[category] = result.get(category, 0) + amount
    return result
totals = reduce(add_total, transactions, {})
print(totals)
# Out:
# {'Savings': 2500, 'Current': 2500}

# %% [markdown]
# ### Q78. Implement retry as a higher-transfer function for banking case 1; use sample reference `ACC-1078` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def retry(func, attempts):
    for _ in range(attempts):
        try:
            return func()
        except ValueError:
            pass
    return "Transfer failed"
count = 0
def transfer():
    global count
    count += 1
    if count < 2:
        raise ValueError("Temporary failure")
    return "Transfer successful"
print(retry(transfer, 3))
# Out:
# Transfer successful

# %% [markdown]
# ### Q79. Create a functional checkout with immutable updates for banking case 1; use sample reference `ACC-1079` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def checkout(account, amount):
    return {**account, "balance": account["balance"] - amount}
account = {"account_id": "ACC-1079", "balance": 10000}
new_account = checkout(account, 2500)
print(new_account)
print(account)
# Out:
# {'account_id': 'ACC-1079', 'balance': 7500}
# {'account_id': 'ACC-1079', 'balance': 10000}

# %% [markdown]
# ### Q80. Design an end-to-end transactions analytics pipeline for banking case 1; use sample reference `ACC-1080` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
transactions = [1000, -500, 2000, 1500, -300]
credits = list(filter(lambda x: x > 0, transactions))
amounts = list(map(lambda x: x * 1.05, credits))
total = reduce(lambda a, b: a + b, amounts, 0)
print("Credits:", credits)
print("After 5%:", amounts)
print("Total:", round(total, 2))
# Out:
# Credits: [1000, 2000, 1500]
# After 5%: [1050.0, 2100.0, 1575.0]
# Total: 4725.0

# %% [markdown]
# ### Q81. Design a configurable transformation pipeline for banking case 2; use sample reference `ACC-1081` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def transform(amount, discount, tax):
    amount = amount * (1 - discount)
    return round(amount * (1 + tax), 2)
print(transform(20000, 0.10, 0.18))
# Out:
# 21240.0

# %% [markdown]
# ### Q82. Implement memoized demand calculation for banking case 2; use sample reference `ACC-1082` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import lru_cache
@lru_cache
def demand(price, quantity):
    return price * quantity
print(demand(500, 10))
print(demand(500, 10))
# Out:
# 5000
# 5000

# %% [markdown]
# ### Q83. Build a decorator with arguments for banking case 2; use sample reference `ACC-1083` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def log_message(message):
    def decorator(func):
        def wrapper(amount):
            print(message)
            return func(amount)
        return wrapper
    return decorator
@log_message("Transaction processed")
def deposit(amount):
    return amount
print(deposit(6000))
# Out:
# Transaction processed
# 6000

# %% [markdown]
# ### Q84. Create a function registry for interest offers for banking case 2; use sample reference `ACC-1084` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def regular(amount):
    return amount * 0.04
def premium(amount):
    return amount * 0.06
offers = {
    "regular": regular,
    "premium": premium
}
print(offers["premium"](10000))
# Out:
# 600.0

# %% [markdown]
# ### Q85. Implement a currying example for amounts for banking case 2; use sample reference `ACC-1085` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def amount(price):
    def total(quantity):
        return price * quantity
    return total
calculate = amount(2000)
print(calculate(3))
# Out:
# 6000

# %% [markdown]
# ### Q86. Compare lazy generators with eager map results for banking case 2; use sample reference `ACC-1086` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
amounts = [1000, 2000, 3000]
lazy = (x * 1.05 for x in amounts)
eager = list(map(lambda x: x * 1.05, amounts))
print(list(lazy))
print(eager)
# Out:
# [1050.0, 2100.0, 3150.0]
# [1050.0, 2100.0, 3150.0]

# %% [markdown]
# ### Q87. Write a robust reduce for grouped totals for banking case 2; use sample reference `ACC-1087` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
transactions = [
    ("Savings", 1000),
    ("Current", 2000),
    ("Savings", 1500)
]
def add_total(result, item):
    category, amount = item
    result[category] = result.get(category, 0) + amount
    return result
print(reduce(add_total, transactions, {}))
# Out:
# {'Savings': 2500, 'Current': 2000}

# %% [markdown]
# ### Q88. Implement retry as a higher-transfer function for banking case 2; use sample reference `ACC-1088` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def retry(func, attempts):
    for _ in range(attempts):
        try:
            return func()
        except ValueError:
            pass
    return "Transfer failed"
count = 0
def transfer():
    global count
    count += 1
    if count < 2:
        raise ValueError("Temporary error")
    return "Transfer successful"
print(retry(transfer, 3))
# Out:
# Transfer successful

# %% [markdown]
# ### Q89. Create a functional checkout with immutable updates for banking case 2; use sample reference `ACC-1089` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def checkout(account, amount):
    return {**account, "balance": account["balance"] - amount}
account = {"account_id": "ACC-1089", "balance": 12000}
new_account = checkout(account, 3000)
print(new_account)
print(account)
# Out:
# {'account_id': 'ACC-1089', 'balance': 9000}
# {'account_id': 'ACC-1089', 'balance': 12000}

# %% [markdown]
# ### Q90. Design an end-to-end transactions analytics pipeline for banking case 2; use sample reference `ACC-1090` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
transactions = [2000, -500, 3000, 1000, -200]
credits = filter(lambda x: x > 0, transactions)
amounts = map(lambda x: x * 1.05, credits)
total = reduce(lambda a, b: a + b, amounts, 0)
print(round(total, 2))
# Out:
# 6300.0

# %% [markdown]
# ### Q91. Design a configurable transformation pipeline for banking case 3; use sample reference `ACC-1091` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def transform(amount, discount, tax):
    amount = amount * (1 - discount)
    return round(amount * (1 + tax), 2)
print(transform(15000, 0.10, 0.18))
# Out:
# 15930.0

# %% [markdown]
# ### Q92. Implement memoized demand calculation for banking case 3; use sample reference `ACC-1092` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import lru_cache
@lru_cache
def demand(price, quantity):
    return price * quantity
print(demand(800, 5))
print(demand(800, 5))
# Out:
# 4000
# 4000

# %% [markdown]
# ### Q93. Build a decorator with arguments for banking case 3; use sample reference `ACC-1093` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def log_message(message):
    def decorator(func):
        def wrapper(amount):
            print(message)
            return func(amount)
        return wrapper
    return decorator
@log_message("Deposit processed")
def deposit(amount):
    return amount
print(deposit(7000))
# Out:
# Deposit processed
# 7000

# %% [markdown]
# ### Q94. Create a function registry for interest offers for banking case 3; use sample reference `ACC-1094` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def regular(amount):
    return amount * 0.04
def premium(amount):
    return amount * 0.06
offers = {"regular": regular, "premium": premium}
print(offers["premium"](15000))
# Out:
# 900.0

# %% [markdown]
# ### Q95. Implement a currying example for amounts for banking case 3; use sample reference `ACC-1095` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def amount(price):
    def total(quantity):
        return price * quantity
    return total
calculate = amount(2500)
print(calculate(4))
# Out:
# 10000

# %% [markdown]
# ### Q96. Compare lazy generators with eager map results for banking case 3; use sample reference `ACC-1096` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
amounts = [1000, 2000, 4000]
lazy = (x * 1.10 for x in amounts)
eager = list(map(lambda x: x * 1.10, amounts))
print(list(lazy))
print(eager)
# Out:
# [1100.0, 2200.0, 4400.0]
# [1100.0, 2200.0, 4400.0]

# %% [markdown]
# ### Q97. Write a robust reduce for grouped totals for banking case 3; use sample reference `ACC-1097` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
transactions = [
    ("Savings", 2000),
    ("Current", 3000),
    ("Savings", 1000)
]
def add_total(result, item):
    category, amount = item
    result[category] = result.get(category, 0) + amount
    return result
print(reduce(add_total, transactions, {}))
# Out:
# {'Savings': 3000, 'Current': 3000}

# %% [markdown]
# ### Q98. Implement retry as a higher-transfer function for banking case 3; use sample reference `ACC-1098` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def retry(func, attempts):
    for _ in range(attempts):
        try:
            return func()
        except ValueError:
            pass
    return "Transfer failed"
count = 0
def transfer():
    global count
    count += 1
    if count < 2:
        raise ValueError("Temporary failure")
    return "Transfer successful"
print(retry(transfer, 3))
# Out:
# Transfer successful

# %% [markdown]
# ### Q99. Create a functional checkout with immutable updates for banking case 3; use sample reference `ACC-1099` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def checkout(account, amount):
    return {**account, "balance": account["balance"] - amount}
account = {"account_id": "ACC-1099", "balance": 15000}
new_account = checkout(account, 4000)
print(new_account)
print(account)
# Out:
# {'account_id': 'ACC-1099', 'balance': 11000}
# {'account_id': 'ACC-1099', 'balance': 15000}

# %% [markdown]
# ### Q100. Design an end-to-end transactions analytics pipeline for banking case 3; use sample reference `ACC-1100` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from functools import reduce
transactions = [3000, -500, 2000, 1000, -200]
credits = filter(lambda x: x > 0, transactions)
amounts = map(lambda x: x * 1.05, credits)
total = reduce(lambda a, b: a + b, amounts, 0)
print(round(total, 2))
